# %%
import pandas as pd

orders = pd.read_csv('/content/orders.csv')
order_items = pd.read_csv('/content/order_items.csv')

# %%
orders.head()
# Out:
#    order_id  user_id     status gender               created_at returned_at  \
# 0         1        2  Cancelled      F  2021-09-06 07:28:00 UTC         NaN
# 1        39       32  Cancelled      F  2020-10-11 15:42:00 UTC         NaN
# 2        48       37  Cancelled      F  2021-12-05 09:25:00 UTC         NaN
# 3        80       56  Cancelled      F  2022-04-22 03:59:00 UTC         NaN
# 4        82       57  Cancelled      F  2023-02-20 11:11:00 UTC         NaN
#
#   shipped_at delivered_at  num_of_item
# 0        NaN          NaN            3
# 1        NaN          NaN            1
# 2        NaN          NaN            1
# 3        NaN          NaN            1
# 4        NaN          NaN            1

# %%
order_items.head()
# Out:
#       id  order_id  user_id  product_id  inventory_item_id      status  \
# 0  47506     32847    26244       14235             128500    Complete
# 1  91827     63707    50812       14235             248119    Complete
# 2  12949      8984     7219       14235              34988     Shipped
# 3  12333      8585     6896       14159              33354    Complete
# 4  68987     47851    38203       14159             186610  Processing
#
#                 created_at               shipped_at             delivered_at  \
# 0  2023-08-26 15:29:27 UTC  2023-08-27 08:18:00 UTC  2023-08-27 18:29:00 UTC
# 1  2020-09-02 16:05:21 UTC  2020-09-04 17:46:00 UTC  2020-09-07 15:35:00 UTC
# 2  2021-12-06 01:19:46 UTC  2021-12-07 12:58:00 UTC                      NaN
# 3  2023-06-17 14:20:58 UTC  2023-06-19 05:18:00 UTC  2023-06-22 09:19:00 UTC
# 4  2019-02-05 16:45:20 UTC                      NaN                      NaN
#
#   returned_at  sale_price
# 0         NaN        0.02
# 1         NaN        0.02
# 2         NaN        0.02
# 3         NaN        0.49
# 4         NaN        0.49

# %%
# This is one is a check I did n orders looking for the first user_id I saw in order_items.head(). And the order_id and user_id are the same ones in both df so we can make a join with both columns.
rows_with_32847 = orders.loc[orders['order_id'] == 32847]
print("where 'order_id' es 32847:")
print(rows_with_32847)
# Out:
# where 'order_id' es 32847:
#        order_id  user_id    status gender               created_at  \
# 13220     32847    26244  Complete      F  2023-08-26 18:23:00 UTC
#
#       returned_at               shipped_at             delivered_at  \
# 13220         NaN  2023-08-27 08:18:00 UTC  2023-08-27 18:29:00 UTC
#
#        num_of_item
# 13220            1

# %%
# not sure about this one because we converted the colum to a datetime and we will need .loc and a... mask? I don't think it's necessary, Leaving it here just in case

# orders['returned_at'] = orders['returned_at'].fillna('non returned')

# %%
orders['returned_at'] = pd.to_datetime(orders['returned_at'], errors='coerce')
orders['shipped_at'] = pd.to_datetime(orders['shipped_at'], errors='coerce')
orders['delivered_at'] = pd.to_datetime(orders['delivered_at'], errors='coerce')
orders['created_at'] = pd.to_datetime(orders['created_at'], errors='coerce')

# %%
order_items.head()
# Out:
#       id  order_id  user_id  product_id  inventory_item_id      status  \
# 0  47506     32847    26244       14235             128500    Complete
# 1  91827     63707    50812       14235             248119    Complete
# 2  12949      8984     7219       14235              34988     Shipped
# 3  12333      8585     6896       14159              33354    Complete
# 4  68987     47851    38203       14159             186610  Processing
#
#                 created_at               shipped_at             delivered_at  \
# 0  2023-08-26 15:29:27 UTC  2023-08-27 08:18:00 UTC  2023-08-27 18:29:00 UTC
# 1  2020-09-02 16:05:21 UTC  2020-09-04 17:46:00 UTC  2020-09-07 15:35:00 UTC
# 2  2021-12-06 01:19:46 UTC  2021-12-07 12:58:00 UTC                      NaN
# 3  2023-06-17 14:20:58 UTC  2023-06-19 05:18:00 UTC  2023-06-22 09:19:00 UTC
# 4  2019-02-05 16:45:20 UTC                      NaN                      NaN
#
#   returned_at  sale_price
# 0         NaN        0.02
# 1         NaN        0.02
# 2         NaN        0.02
# 3         NaN        0.49
# 4         NaN        0.49

# %%
orders = orders.dropna(subset=['shipped_at', 'delivered_at'])

# %%
orders.to_csv('/content/orders_new.csv', index=False)

# %%
# Checking
order_items.head()
# Out:
#       id  order_id  user_id  product_id  inventory_item_id      status  \
# 0  47506     32847    26244       14235             128500    Complete
# 1  91827     63707    50812       14235             248119    Complete
# 2  12949      8984     7219       14235              34988     Shipped
# 3  12333      8585     6896       14159              33354    Complete
# 4  68987     47851    38203       14159             186610  Processing
#
#                 created_at               shipped_at             delivered_at  \
# 0  2023-08-26 15:29:27 UTC  2023-08-27 08:18:00 UTC  2023-08-27 18:29:00 UTC
# 1  2020-09-02 16:05:21 UTC  2020-09-04 17:46:00 UTC  2020-09-07 15:35:00 UTC
# 2  2021-12-06 01:19:46 UTC  2021-12-07 12:58:00 UTC                      NaN
# 3  2023-06-17 14:20:58 UTC  2023-06-19 05:18:00 UTC  2023-06-22 09:19:00 UTC
# 4  2019-02-05 16:45:20 UTC                      NaN                      NaN
#
#   returned_at  sale_price
# 0         NaN        0.02
# 1         NaN        0.02
# 2         NaN        0.02
# 3         NaN        0.49
# 4         NaN        0.49

# %%
orders.dtypes
# Out:
# order_id                      int64
# user_id                       int64
# status                       object
# gender                       object
# created_at      datetime64[ns, UTC]
# returned_at     datetime64[ns, UTC]
# shipped_at      datetime64[ns, UTC]
# delivered_at    datetime64[ns, UTC]
# num_of_item                   int64
# dtype: object

# %%
orderitems_plus_orders = pd.merge(order_items, orders,
                             left_on=['order_id', 'user_id'],
                             right_on=['order_id', 'user_id'],
                             how='left',
                             suffixes=('_item_orders', '_orders'))

orderitems_plus_orders = orderitems_plus_orders.drop(columns=['created_at_item_orders', "shipped_at_item_orders", "delivered_at_item_orders", "returned_at_item_orders"])

# %%
orderitems_plus_orders.head()
# Out:
#       id  order_id  user_id  product_id  inventory_item_id status_item_orders  \
# 0  47506     32847    26244       14235             128500           Complete
# 1  91827     63707    50812       14235             248119           Complete
# 2  12949      8984     7219       14235              34988            Shipped
# 3  12333      8585     6896       14159              33354           Complete
# 4  68987     47851    38203       14159             186610         Processing
#
#    sale_price status_orders gender created_at_orders returned_at_orders  \
# 0        0.02           NaN    NaN               NaT                NaT
# 1        0.02           NaN    NaN               NaT                NaT
# 2        0.02           NaN    NaN               NaT                NaT
# 3        0.49           NaN    NaN               NaT                NaT
# 4        0.49           NaN    NaN               NaT                NaT
#
#   shipped_at_orders delivered_at_orders  num_of_item
# 0               NaT                 NaT          NaN
# 1               NaT                 NaT          NaN
# 2               NaT                 NaT          NaN
# 3               NaT                 NaT          NaN
# 4               NaT                 NaT          NaN

# %%
orderitems_plus_orders.rename(columns={'created_at_orders': 'created_at', 'returned_at_orders': 'returned_at', 'shipped_at_orders': 'shipped_at', 'delivered_at_orders': 'delivered_at'}, inplace=True)

# %%
orderitems_plus_orders.dtypes
# Out:
# id                                  int64
# order_id                            int64
# user_id                             int64
# product_id                          int64
# inventory_item_id                   int64
# status_item_orders                 object
# sale_price                        float64
# status_orders                      object
# gender                             object
# created_at            datetime64[ns, UTC]
# returned_at           datetime64[ns, UTC]
# shipped_at            datetime64[ns, UTC]
# delivered_at          datetime64[ns, UTC]
# num_of_item                       float64
# dtype: object

# %%
orderitems_plus_orders.to_csv('orderitems_plus_orders.csv', index=False)

# %%
from google.colab import files
files.download('/content/orderitems_plus_orders.csv')
