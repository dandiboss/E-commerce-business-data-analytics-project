# %%
import pandas as pd

users = pd.read_csv('/content/users.csv')

users.head()
# Out:
#       id first_name  last_name                         email  age gender  \
# 0   1273     Joseph    Johnson     josephjohnson@example.org   55      M
# 1   3895      Jason  Henderson    jasonhenderson@example.com   14      M
# 2   4198    Kenneth  Velasquez  kennethvelasquez@example.org   39      M
# 3  32658    Patrick   Williams   patrickwilliams@example.org   26      M
# 4  37198      Susan      Adams        susanadams@example.net   33      F
#
#   state                 street_address postal_code         city country  \
# 0  Acre               259 Johnny Roads   69980-000  Desconocido  Brasil
# 1  Acre  58574 Caitlin Spurs Suite 869   69980-000  Desconocido  Brasil
# 2  Acre          38640 Shannon Streets   69980-000  Desconocido  Brasil
# 3  Acre    2732 Danielle Rest Apt. 114   69980-000  Desconocido  Brasil
# 4  Acre           81570 Schultz Bypass   69980-000  Desconocido  Brasil
#
#    latitude  longitude traffic_source               created_at
# 0 -8.065346 -72.870949         Search  2020-07-17 10:15:00 UTC
# 1 -8.065346 -72.870949        Organic  2022-08-05 18:06:00 UTC
# 2 -8.065346 -72.870949         Search  2021-03-11 11:42:00 UTC
# 3 -8.065346 -72.870949         Search  2022-12-18 11:54:00 UTC
# 4 -8.065346 -72.870949         Search  2021-10-19 06:18:00 UTC

# %%
missing_values_users = users.isnull().sum()
print("NUll values:\n", missing_values_users)
# Out:
# NUll values:
#  id                0
# first_name        0
# last_name         0
# email             0
# age               0
# gender            0
# state             0
# street_address    0
# postal_code       0
# city              0
# country           0
# latitude          0
# longitude         0
# traffic_source    0
# created_at        0
# dtype: int64

# %%
users.fillna('unknown', inplace=True)

users.to_csv('/content/users_cleaned.csv', index=False)

# %%
users['city'].fillna('unknown', inplace=True)

# %%
edades_invalidas = users[(users['age'] < 18) | (users['age'] > 100)]
print(f"users underage:\n{edades_invalidas}")
# Out:
# users underage:
#           id first_name   last_name                          email  age  \
# 1       3895      Jason   Henderson     jasonhenderson@example.com   14
# 15     19844     Autumn      Harper       autumnharper@example.com   13
# 19     43249      Casey       Moses         caseymoses@example.com   17
# 32     30545    Timothy  Valenzuela  timothyvalenzuela@example.net   12
# 35     45895      Tyler     Spencer       tylerspencer@example.com   15
# ...      ...        ...         ...                            ...  ...
# 99974  18165   Michelle     Parsons    michelleparsons@example.org   13
# 99982  45440     Justin        Carr         justincarr@example.org   17
# 99987  38255       Mary      Miller         marymiller@example.net   16
# 99992  82303  Stephanie       Wiley     stephaniewiley@example.com   13
# 99999  31708       Brad    Anderson       bradanderson@example.net   14
#
#       gender          state                  street_address postal_code  \
# 1          M           Acre   58574 Caitlin Spurs Suite 869   69980-000
# 15         F           Acre                   0664 Tom Cove   69970-000
# 19         F           Acre           996 Blanchard Station   69970-000
# 32         M           Acre  532 Rodriguez Divide Suite 498   69917-400
# 35         M           Acre              74299 Smith Plains   69917-400
# ...      ...            ...                             ...         ...
# 99974      F  Île-de-France          6343 Andrews Junctions       77450
# 99982      M  Île-de-France              5971 Martinez Lock       77130
# 99987      F  Île-de-France     51376 Jason Ranch Suite 769       77370
# 99992      F  Île-de-France        71565 Day Road Suite 295       77120
# 99999      M  Île-de-France                 2021 Sarah Club       77320
#
#                      city country   latitude  longitude traffic_source  \
# 1             Desconocido  Brasil  -8.065346 -72.870949        Organic
# 15               Tarauacá  Brasil  -8.325245 -71.553030        Display
# 19               Tarauacá  Brasil  -8.325245 -71.553030        Organic
# 32             Rio Branco  Brasil  -9.945568 -67.835610         Search
# 35             Rio Branco  Brasil  -9.945568 -67.835610        Display
# ...                   ...     ...        ...        ...            ...
# 99974          Trilbardou  France  48.919739   2.802879         Search
# 99982  La Grande-Paroisse  France  48.378520   2.963704         Search
# 99987    La Croix-en-Brie  France  48.560593   3.037547         Search
# 99992    Beautheil-Saints  France  48.789740   3.095796         Search
# 99999      Choisy-en-Brie  France  48.763993   3.319993         Search
#
#                     created_at
# 1      2022-08-05 18:06:00 UTC
# 15     2024-03-05 18:18:00 UTC
# 19     2023-08-03 04:36:00 UTC
# 32     2024-07-27 00:57:00 UTC
# 35     2024-05-25 02:44:00 UTC
# ...                        ...
# 99974  2019-04-13 17:00:00 UTC
# 99982  2020-11-04 16:58:00 UTC
# 99987  2019-02-11 06:39:00 UTC
# 99992  2021-01-22 16:21:00 UTC
# 99999  2021-05-01 03:12:00 UTC
#
# [10323 rows x 15 columns]

# %%
import pandas as pd

from google.colab import files

users.to_csv('/content/users_new.csv', index=False)
users.to_csv('/content/users.csv', index=False)

files.download('/content/users_new.csv')

# %% [markdown]
# ANALISIS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
sns.countplot(x='gender', data=df_users)
plt.title('by gender')

gender_counts = df_users['gender'].value_counts()
print(gender_counts)
# Out:
# gender
# F    50230
# M    49770
# Name: count, dtype: int64

# %%
sns.set(style="whitegrid")

plt.figure(figsize=(10, 6))
sns.barplot(y=age_group_counts.index.astype(str),
            x=age_group_counts.values,
            hue=age_group_counts.index.astype(str),
            dodge=False,
            palette="Blues_d",
            edgecolor='black',
            legend=False)
for i, count in enumerate(age_group_counts.values):
    plt.text(count + 100, i, str(count), va='center', ha='left', fontsize=10, fontweight='bold', color='black')
plt.title("Consume by age)", fontsize=12, fontweight='bold')
plt.xlabel("number of people", fontsize=14)
plt.ylabel("Age", fontsize=14)
plt.show()

# %%
plt.figure(figsize=(8, 5))
top_countries = df_users['country'].value_counts().head(10)
sns.barplot(x=top_countries.values, y=top_countries.index,
            hue=top_countries.index, palette='coolwarm',
            dodge=False, legend=False)
plt.title('Countries', fontsize=16)
# Out:
# Text(0.5, 1.0, 'Countries')

# %%
plt.figure(figsize=(10, 6))
top_cities = users['city'].value_counts().head(10)

sns.barplot(x=top_cities.values, y=top_cities.index,
            hue=top_cities.index, palette='coolwarm',
            dodge=False, legend=False)
plt.title('Cities', fontsize=16)
plt.tight_layout()
plt.show()
